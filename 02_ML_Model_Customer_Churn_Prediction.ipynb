# %%
import joblib
import warnings
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("customer_churn_data.csv")

# %%
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
y = data[["Churn"]]
X = data[["Age", "Gender", "Tenure", "MonthlyCharges"]]

# %%
X
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
X["Gender"] = X["Gender"].apply(lambda x: 1 if x == 'Female' else 0)
# Out:
# C:\Users\mhasn\AppData\Local\Temp\ipykernel_54416\3907384182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Gender"] = X["Gender"].apply(lambda x: 1 if x == 'Female' else 0)

# %%
y
# Out:
#     Churn
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# ..    ...
# 995   Yes
# 996   Yes
# 997   Yes
# 998   Yes
# 999   Yes
#
# [1000 rows x 1 columns]

# %%
y["Churn"] = y["Churn"].apply(lambda x:1 if x == "Yes" else 0)
# Out:
# C:\Users\mhasn\AppData\Local\Temp\ipykernel_54416\3104515624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["Churn"] = y["Churn"].apply(lambda x:1 if x == "Yes" else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 554   48       0      21           67.59
# 148   50       1      11          118.30
# 452   35       1      33           66.22
# 618   49       0       5          116.92
# 206   50       0      17          119.75
# ..   ...     ...     ...             ...
# 376   53       1      24           95.21
# 265   32       0      24          104.01
# 135   60       1      35          119.16
# 932   30       0       2           71.96
# 917   46       1      23           51.04
#
# [800 rows x 4 columns]

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.33670116, -1.05925253,  0.114604  , -0.27111756],
#        [ 0.53938056,  0.94406194, -0.41720109,  1.71671137],
#        [-0.98071497,  0.94406194,  0.7527701 , -0.32482148],
#        ...,
#        [ 1.55277759,  0.94406194,  0.85913111,  1.75042332],
#        [-1.48741348, -1.05925253, -0.89582566, -0.09981383],
#        [ 0.13402176,  0.94406194,  0.22096501, -0.91987656]])

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.17497509,  0.85972695, -0.39008203,  1.74109294],
#        [-0.28038177,  0.85972695,  0.44376065, -1.32056676],
#        [-0.80741516, -1.16316   ,  1.69452467, -0.46758398],
#        [ 0.66827834,  0.85972695,  0.18318481,  1.73504073],
#        [ 1.30071842,  0.85972695, -0.7548882 , -0.65444584],
#        [-0.91282184,  0.85972695,  0.07895448,  0.99213245],
#        [ 0.03583827,  0.85972695, -0.65065787, -0.59997598],
#        [-0.5966018 , -1.16316   ,  0.96491233, -0.18993903],
#        [ 0.66827834,  0.85972695, -0.9112337 , -0.38360962],
#        [-0.49119512, -1.16316   ,  0.18318481, -0.8810253 ],
#        [-0.28038177, -1.16316   , -0.39008203,  0.21858488],
#        [ 1.08990506, -1.16316   ,  1.38183367, -1.57400288],
#        [-1.96688863, -1.16316   , -0.4421972 ,  1.66544037],
#        [ 0.8790917 ,  0.85972695,  0.28741515, -0.99299111],
#        [-0.06956841,  0.85972695,  0.02683931, -1.18401386],
#        [-1.22904187, -1.16316   , -0.12950619,  1.54401798],
#        [-1.54526191,  0.85972695,  0.91279716, -0.54928876],
#        [ 0.14124495,  0.85972695, -0.9112337 , -0.06965143],
#        [ 0.35205831, -1.16316   ,  0.49587582, -1.62658142],
#        [-1.33444855,  0.85972695,  0.07895448, -0.94495172],
#        [ 0.35205831,  0.85972695,  0.60010615, -1.02249561],
#        [ 2.46019188,  0.85972695, -1.01546404, -1.37201051],
#        [ 1.40612509, -1.16316   , -0.80700337, -0.12374303],
#        [ 0.45746499,  0.85972695,  2.63259769, -0.21112175],
#        [ 0.77368502, -1.16316   , -0.23373653,  0.13461052],
#        [-0.5966018 , -1.16316   , -0.7548882 , -0.41992285],
#        [ 0.03583827,  0.85972695,  0.07895448,  1.0904808 ],
#        [-0.91282184,  0.85972695,  0.86068199,  1.04773709],
#        [-0.28038177, -1.16316   ,  1.12125783, -1.39168018],
#        [-0.80741516,  0.85972695,  2.47625219,  0.63543056],
#        [ 0.03583827,  0.85972695, -0.7548882 , -0.54437134],
#        [ 0.8790917 , -1.16316   , -0.4421972 ,  0.17773248],
#        [ 0.24665163, -1.16316   ,  1.53817917,  0.20421089],
#        [ 0.66827834, -1.16316   , -0.54642753, -0.81180319],
#        [-0.17497509,  0.85972695, -0.85911854, -0.4520752 ],
#        [ 0.8790917 ,  0.85972695,  1.27760333, -0.31627883],
#        [-0.5966018 ,  0.85972695,  1.173373  ,  1.10409826],
#        [ 0.77368502,  0.85972695, -0.02527586,  0.69027868],
#        [ 0.77368502,  0.85972695,  0.49587582,  0.30482881],
#        [-1.01822852, -1.16316   ,  0.07895448, -0.20317823],
#        [-1.33444855, -1.16316   ,  1.27760333, -0.91090806],
#        [-0.49119512,  0.85972695,  1.59029434,  1.53304836],
#        [-1.43985523, -1.16316   ,  0.80856682,  1.72785374],
#        [-0.17497509,  0.85972695, -0.9112337 , -1.36558004],
#        [-0.06956841,  0.85972695, -0.85911854, -1.3027884 ],
#        [ 0.45746499, -1.16316   , -0.96334887, -1.17115292],
#        [-0.80741516, -1.16316   ,  0.13106965,  1.43356522],
#        [ 1.30071842, -1.16316   ,  0.39164548, -1.03119566],
#        [ 0.14124495,  0.85972695,  0.28741515,  0.684983  ],
#        [ 0.14124495,  0.85972695,  0.33953032, -1.64019888],
#        [-0.06956841, -1.16316   , -0.96334887,  0.30558534],
#        [-0.5966018 ,  0.85972695, -0.54642753,  0.55032142],
#        [ 1.51153177,  0.85972695, -0.28585169,  1.34505171],
#        [ 0.66827834,  0.85972695, -0.23373653,  1.42940433],
#        [-0.80741516, -1.16316   ,  0.44376065, -1.55055058],
#        [ 0.77368502, -1.16316   ,  1.12125783,  0.28742872],
#        [-1.1236352 ,  0.85972695, -0.96334887,  0.17773248],
#        [-0.06956841, -1.16316   , -0.96334887, -1.65949029],
#        [ 0.24665163,  0.85972695, -0.9112337 ,  1.43091738],
#        [ 0.8790917 , -1.16316   ,  0.91279716,  0.36497261],
#        [-1.01822852, -1.16316   , -0.70277303,  1.17369863],
#        [ 0.98449838,  0.85972695, -0.49431236, -0.01215548],
#        [ 0.56287166,  0.85972695, -0.49431236, -0.4683405 ],
#        [ 0.45746499, -1.16316   ,  1.43394883,  0.16978896],
#        [ 2.3547852 ,  0.85972695, -0.80700337, -0.87421657],
#        [-1.1236352 ,  0.85972695, -0.18162136,  0.36345956],
#        [-0.28038177,  0.85972695, -0.07739102,  0.64072624],
#        [-0.38578844, -1.16316   ,  0.18318481,  0.6085739 ],
#        [ 0.66827834,  0.85972695,  1.95510051, -0.89161666],
#        [-1.01822852, -1.16316   , -0.85911854,  0.26700252],
#        [ 0.66827834, -1.16316   , -0.12950619,  0.23447192],
#        [ 1.19531174,  0.85972695, -0.18162136,  0.7716052 ],
#        [ 1.82775181, -1.16316   , -0.70277303,  1.69948402],
#        [ 0.03583827,  0.85972695,  0.49587582,  1.51527   ],
#        [-0.17497509,  0.85972695, -0.70277303,  0.85368824],
#        [-1.65066859, -1.16316   ,  3.1016342 ,  0.35665082],
#        [ 0.66827834,  0.85972695, -0.9112337 ,  0.59079554],
#        [-1.43985523, -1.16316   , -0.9112337 , -0.72253315],
#        [ 2.56559856, -1.16316   , -0.7548882 , -1.52823307],
#        [ 0.35205831,  0.85972695, -1.01546404,  0.96905842],
#        [-0.06956841,  0.85972695, -0.07739102,  0.9437148 ],
#        [-0.17497509, -1.16316   ,  0.23529998, -1.14429626],
#        [ 0.8790917 ,  0.85972695,  2.42413702,  0.9906194 ],
#        [ 0.24665163,  0.85972695, -0.54642753,  1.3064689 ],
#        [ 0.56287166,  0.85972695, -0.70277303,  1.21530755],
#        [ 1.82775181, -1.16316   , -0.02527586, -0.80045531],
#        [ 0.77368502,  0.85972695,  2.42413702,  0.26586773],
#        [-0.17497509,  0.85972695,  0.28741515,  1.62458798],
#        [-1.54526191,  0.85972695, -0.9112337 ,  0.59079554],
#        [ 1.51153177, -1.16316   , -0.02527586,  1.63820544],
#        [ 1.61693845, -1.16316   , -0.28585169,  0.24165891],
#        [ 1.51153177,  0.85972695, -0.7548882 ,  0.29348092],
#        [ 0.35205831,  0.85972695, -0.33796686, -0.36810084],
#        [-1.43985523,  0.85972695, -0.54642753,  1.41692166],
#        [-0.28038177,  0.85972695,  2.11144601, -0.27353512],
#        [-0.28038177,  0.85972695, -0.28585169, -1.03913918],
#        [-0.49119512,  0.85972695, -1.01546404, -1.49002852],
#        [-1.86148195, -1.16316   , -0.28585169,  0.79884012],
#        [-0.49119512,  0.85972695, -0.80700337,  1.33181251],
#        [-0.06956841,  0.85972695, -0.39008203,  1.18882915],
#        [-0.91282184, -1.16316   , -0.28585169, -1.02627824],
#        [ 0.77368502,  0.85972695,  0.54799099, -0.87875572],
#        [ 0.8790917 ,  0.85972695, -0.96334887,  1.64009675],
#        [ 0.35205831,  0.85972695, -0.49431236, -1.25172291],
#        [ 0.98449838, -1.16316   , -0.54642753, -0.73766367],
#        [-2.81014206,  0.85972695, -0.65065787, -1.37541487],
#        [-0.06956841, -1.16316   , -0.85911854,  1.47479588],
#        [-0.28038177, -1.16316   ,  0.60010615, -0.61851086],
#        [-0.28038177,  0.85972695,  0.91279716, -0.15438232],
#        [ 0.14124495, -1.16316   ,  0.28741515, -1.43555867],
#        [ 1.19531174,  0.85972695, -0.28585169, -0.12941697],
#        [-1.75607527,  0.85972695, -0.9112337 , -0.02047726],
#        [-1.54526191,  0.85972695,  0.54799099, -1.51915476],
#        [-1.54526191,  0.85972695,  0.23529998, -0.20658259],
#        [-1.75607527, -1.16316   , -0.23373653,  1.49824818],
#        [ 0.35205831,  0.85972695, -0.96334887, -1.4688458 ],
#        [-0.5966018 , -1.16316   , -0.39008203,  1.40292593],
#        [ 0.98449838,  0.85972695,  2.89317353, -1.61523353],
#        [ 0.03583827,  0.85972695,  0.13106965, -0.07759495],
#        [ 0.66827834,  0.85972695, -0.39008203,  0.07408846],
#        [-0.91282184,  0.85972695,  2.89317353,  1.63971849],
#        [ 2.67100524, -1.16316   ,  0.80856682, -1.58118988],
#        [-0.5966018 , -1.16316   , -0.96334887,  0.62975662],
#        [ 0.24665163,  0.85972695, -0.85911854,  0.14898451],
#        [-2.17770198, -1.16316   ,  2.11144601, -0.39041835],
#        [ 0.8790917 , -1.16316   ,  4.14393755,  1.51300043],
#        [-1.22904187, -1.16316   , -0.65065787, -0.55458444],
#        [ 0.03583827, -1.16316   , -0.65065787, -0.7474985 ],
#        [-0.80741516,  0.85972695,  0.39164548,  0.81775327],
#        [ 0.8790917 ,  0.85972695, -1.01546404, -0.2890439 ],
#        [ 0.56287166, -1.16316   , -0.12950619,  1.33143425],
#        [ 0.35205831,  0.85972695, -0.12950619, -1.11290044],
#        [-1.1236352 ,  0.85972695, -0.12950619, -0.79251178],
#        [ 0.14124495,  0.85972695, -0.02527586,  0.30218097],
#        [ 2.14397185,  0.85972695, -0.65065787, -1.06561758],
#        [-1.1236352 ,  0.85972695, -0.33796686,  0.751179  ],
#        [-0.80741516, -1.16316   , -0.96334887, -0.30152658],
#        [ 0.56287166,  0.85972695, -0.85911854, -1.37730619],
#        [ 0.03583827, -1.16316   ,  0.18318481,  1.18088562],
#        [ 0.56287166, -1.16316   ,  0.02683931,  1.34959087],
#        [-1.22904187,  0.85972695, -0.70277303, -1.01303904],
#        [ 0.24665163, -1.16316   ,  0.75645166, -0.91998637],
#        [ 0.77368502,  0.85972695, -0.96334887,  1.44075222],
#        [-0.38578844,  0.85972695, -0.12950619, -0.45358825],
#        [ 0.24665163,  0.85972695, -0.80700337,  1.39649546],
#        [ 0.8790917 , -1.16316   ,  2.31990668,  0.94787569],
#        [ 2.24937852,  0.85972695, -1.01546404,  0.4618079 ],
#        [ 0.14124495,  0.85972695, -0.18162136,  1.23195111],
#        [-0.49119512,  0.85972695, -0.02527586, -1.42799341],
#        [ 1.19531174,  0.85972695, -0.80700337,  1.72747548],
#        [ 0.03583827,  0.85972695, -0.80700337,  0.38388575],
#        [ 0.45746499,  0.85972695,  0.70433649,  0.4822341 ],
#        [ 0.45746499,  0.85972695, -0.9112337 , -0.19334339],
#        [-0.28038177,  0.85972695, -0.96334887, -0.11617777],
#        [-0.5966018 , -1.16316   , -0.65065787,  0.61197826],
#        [-0.5966018 , -1.16316   , -0.07739102,  0.2325806 ],
#        [-0.5966018 ,  0.85972695,  1.38183367,  0.44743391],
#        [-1.65066859, -1.16316   ,  0.13106965,  0.2855374 ],
#        [-0.06956841,  0.85972695, -0.39008203, -1.20065743],
#        [ 0.45746499, -1.16316   , -0.49431236, -1.21578794],
#        [-0.28038177,  0.85972695, -0.5985427 , -1.13597447],
#        [-1.01822852,  0.85972695, -0.49431236,  1.23384243],
#        [-1.1236352 , -1.16316   , -0.9112337 , -0.58068458],
#        [ 0.03583827, -1.16316   , -0.28585169, -0.77775953],
#        [-0.49119512, -1.16316   , -0.28585169, -1.40038022],
#        [-0.17497509, -1.16316   , -0.5985427 , -1.43291083],
#        [ 0.66827834, -1.16316   , -0.39008203, -1.02930434],
#        [-0.5966018 ,  0.85972695,  1.12125783,  0.57415198],
#        [ 0.56287166, -1.16316   , -0.65065787,  0.66077417],
#        [-0.06956841, -1.16316   , -0.85911854, -0.4785536 ],
#        [ 0.35205831, -1.16316   ,  3.88336171,  0.59155207],
#        [ 0.03583827, -1.16316   ,  0.54799099,  1.64425764],
#        [ 0.66827834, -1.16316   , -0.02527586,  0.14747146],
#        [-0.80741516, -1.16316   , -0.9112337 , -1.33834511],
#        [ 0.66827834, -1.16316   , -0.96334887,  0.40506847],
#        [-0.5966018 , -1.16316   , -0.33796686,  0.21971966],
#        [ 0.8790917 ,  0.85972695, -0.4421972 ,  0.37026829],
#        [ 0.24665163,  0.85972695, -0.70277303, -0.11352993],
#        [ 1.08990506, -1.16316   , -0.5985427 ,  0.89983631],
#        [-1.54526191,  0.85972695,  0.54799099, -0.06813838],
#        [-0.5966018 ,  0.85972695,  1.53817917, -0.73690714],
#        [ 1.08990506,  0.85972695,  0.02683931, -0.93019947],
#        [ 0.24665163,  0.85972695,  0.39164548,  0.18113685],
#        [-2.81014206,  0.85972695,  0.96491233, -1.62317705],
#        [-0.28038177, -1.16316   , -0.54642753, -1.10684823],
#        [ 1.93315849, -1.16316   , -0.28585169,  0.59079554],
#        [-0.5966018 , -1.16316   , -0.39008203, -1.52936786],
#        [ 0.03583827,  0.85972695, -0.54642753, -0.83298591],
#        [ 0.35205831, -1.16316   , -1.01546404,  1.09539822],
#        [-0.17497509,  0.85972695, -0.33796686, -0.43127074],
#        [-0.5966018 , -1.16316   ,  2.52836735, -0.3124962 ],
#        [-0.49119512,  0.85972695, -0.7548882 ,  0.50946902],
#        [-0.49119512,  0.85972695, -0.7548882 , -1.26571864],
#        [ 1.30071842, -1.16316   , -0.54642753,  0.43911213],
#        [-3.44258213,  0.85972695, -0.96334887, -1.38184534],
#        [ 0.35205831, -1.16316   , -0.80700337,  0.40431195],
#        [-0.06956841,  0.85972695, -1.01546404, -0.27126555],
#        [ 0.35205831,  0.85972695,  0.23529998, -1.63339015],
#        [ 0.66827834,  0.85972695, -0.7548882 ,  1.12112009],
#        [ 0.77368502, -1.16316   , -0.23373653,  1.12074183]])

# %%
def modelperformance(prediction):
    print(f"Accuracy score on the model is: {accuracy_score(y_test, prediction)}")

# %%
log_model = LogisticRegression()
log_model
# Out:
# LogisticRegression()

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_model_pred = log_model.predict(X_test)

# %%
modelperformance(log_model_pred)
# Out:
# Accuracy score on the model is: 0.89

# %%
knc = KNeighborsClassifier()
knc
# Out:
# KNeighborsClassifier()

# %%
param_grid = {
    'n_neighbors':[3,5,7,9,11],
    'weights': ['uniform', 'distance']
}

# %%
gridkn = GridSearchCV(knc,param_grid,cv=5)

# %%
gridkn.best_params_
# Out:
# {'n_neighbors': 5, 'weights': 'uniform'}

# %%
gridkn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
kn_pred = gridkn.predict(X_test)

# %%
modelperformance(kn_pred)
# Out:
# Accuracy score on the model is: 0.88

# %%
svc = SVC()
svc
# Out:
# SVC()

# %%
param_grid = {
    "C":[0.01, 0.1, 0.5, 1],
    "kernel": ['linear', 'rbf', 'poly']
}

# %%
gridsvc = GridSearchCV(svc, param_grid, cv=5)

# %%
gridsvc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
gridsvc.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}

# %%
svc_pred = gridsvc.predict(X_test)

# %%
modelperformance(svc_pred)
# Out:
# Accuracy score on the model is: 0.9

# %%
dt = DecisionTreeClassifier()
dt
# Out:
# DecisionTreeClassifier()

# %%
param_grid = {
    'criterion':['entropy', 'gini'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
griddt = GridSearchCV(dt, param_grid, cv=5)

# %%
griddt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
griddt.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 30,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
dt_pred = griddt.predict(X_test)

# %%
modelperformance(dt_pred)
# Out:
# Accuracy score on the model is: 0.845

# %%
rfc = RandomForestClassifier()
rfc
# Out:
# RandomForestClassifier()

# %%
param_grid = {
    'n_estimators': [32, 64, 128, 256],
    'max_features': [2,3,4],
    'bootstrap': [True, False]
}

# %%
gridrfc = GridSearchCV(rfc, param_grid, cv=5)

# %%
gridrfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256]})

# %%
gridrfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 256}

# %%
rfc_pred = gridrfc.predict(X_test)

# %%
modelperformance(rfc_pred)
# Out:
# Accuracy score on the model is: 0.885

# %%
best_model = gridsvc.best_estimator_
best_model
# Out:
# SVC(C=0.01, kernel='linear')

# %%
joblib.dump(best_model, 'model.pkl')
# Out:
# ['model.pkl']
